# %%
import pandas as pd 
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
# Read in the data
INPUT_DIR = '../Data'
cal = pd.read_csv(f'{INPUT_DIR}/calendar.csv')
stv = pd.read_csv(f'{INPUT_DIR}/sales_train_validation.csv')
ss = pd.read_csv(f'{INPUT_DIR}/sample_submission.csv')
sellp = pd.read_csv(f'{INPUT_DIR}/sell_prices.csv')

# %% [markdown]
# # Only do FOODS_3_090_CA_3_validation!

# %%
stv[(stv.item_id=='FOODS_3_090') & (stv.id=='FOODS_3_090_CA_3_validation')]
# Out:
#                                id      item_id  dept_id cat_id store_id  \
# 8412  FOODS_3_090_CA_3_validation  FOODS_3_090  FOODS_3  FOODS     CA_3
#
#      state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  \
# 8412       CA  108  132  102  120  ...     129     160     204      86
#
#       d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 8412     100      88      77     141     139     130
#
# [1 rows x 1919 columns]

# %%
sellp.head(1)
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58

# %%
data.head()
# Out:
#   index  8412  wm_yr_wk    weekday  wday  month  year event_name_1  \
# 0   d_1   108     11101   Saturday     1      1  2011          NaN
# 1   d_2   132     11101     Sunday     2      1  2011          NaN
# 2   d_3   102     11101     Monday     3      1  2011          NaN
# 3   d_4   120     11101    Tuesday     4      2  2011          NaN
# 4   d_5   106     11101  Wednesday     5      2  2011          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_TX
# 0          NaN          NaN          NaN        0
# 1          NaN          NaN          NaN        0
# 2          NaN          NaN          NaN        0
# 3          NaN          NaN          NaN        1
# 4          NaN          NaN          NaN        0

# %%
data=stv[stv.id=='FOODS_3_090_CA_3_validation'] 
data=data.iloc[:,6:].T
data=data.reset_index()
data=data.merge(cal, left_on='index', right_on='d')

wm_yr_wk_unique=data.wm_yr_wk.unique()

# %%
# %%time
#Transform
product_id='FOODS_3_090_CA_3_validation'
df=pd.DataFrame({})

data=stv[stv.id==product_id].iloc[:,6:].T.reset_index()
data=data.merge(cal, left_on='index', right_on='d')
data=data.drop(['d','snap_CA', 'snap_WI','date'],axis=1)

#Get the prices
store_id='_'.join(product_id.split('_')[3:5])
item_id='_'.join(product_id.split('_')[:3])

df_price=sellp[sellp.item_id==item_id]
df_price=df_price[(df_price.store_id==store_id)]
df_price=df_price[df_price.wm_yr_wk.isin(wm_yr_wk_unique)]

#Merge it
data=data.merge(df_price, on='wm_yr_wk' )
# Out:
# CPU times: user 368 ms, sys: 8.39 ms, total: 376 ms
# Wall time: 384 ms

# %%
data.head(1)
# Out:
#   index  8412  wm_yr_wk   weekday  wday  month  year event_name_1  \
# 0   d_1   108     11101  Saturday     1      1  2011          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_TX store_id      item_id  \
# 0          NaN          NaN          NaN        0     CA_3  FOODS_3_090
#
#    sell_price
# 0        1.25

# %%
#Categorical data
data=pd.concat([data,pd.get_dummies(data[['weekday','event_name_1',
                                          'event_name_2','event_type_1'
                                          ,'event_type_2']])],axis=1)
data=data.drop(['store_id','item_id','weekday','event_name_1',
                'event_name_2','event_type_1',
                'event_type_2','index'],axis=1)

# %%
data['lag_t28']=data[8412].transform(lambda x: x.shift(28))
data['lag_t29'] = data[8412].transform(lambda x: x.shift(29))
data['lag_t30'] = data[8412].transform(lambda x: x.shift(30))
data['rolling_mean_t30'] = data[8412].transform(lambda x: x.shift(28).rolling(30).mean())
data['rolling_mean_t90'] = data[8412].transform(lambda x: x.shift(28).rolling(90).mean())
data['rolling_mean_t180'] = data[8412].transform(lambda x: x.shift(28).rolling(180).mean())
data['price_lag_1'] = data['sell_price'].transform(lambda x: x.shift(1))

# nan till row 205

# %%
data.head()
# Out:
#    8412  wm_yr_wk  wday  month  year  snap_TX  sell_price  weekday_Friday  \
# 0   108     11101     1      1  2011        0        1.25               0
# 1   132     11101     2      1  2011        0        1.25               0
# 2   102     11101     3      1  2011        0        1.25               0
# 3   120     11101     4      2  2011        1        1.25               0
# 4   106     11101     5      2  2011        0        1.25               0
#
#    weekday_Monday  weekday_Saturday  ...  event_type_1_Sporting  \
# 0               0                 1  ...                      0
# 1               0                 0  ...                      0
# 2               1                 0  ...                      0
# 3               0                 0  ...                      0
# 4               0                 0  ...                      0
#
#    event_type_2_Cultural  event_type_2_Religious  lag_t28  lag_t29  lag_t30  \
# 0                      0                       0      NaN      NaN      NaN
# 1                      0                       0      NaN      NaN      NaN
# 2                      0                       0      NaN      NaN      NaN
# 3                      0                       0      NaN      NaN      NaN
# 4                      0                       0      NaN      NaN      NaN
#
#    rolling_mean_t30  rolling_mean_t90  rolling_mean_t180  price_lag_1
# 0               NaN               NaN                NaN          NaN
# 1               NaN               NaN                NaN         1.25
# 2               NaN               NaN                NaN         1.25
# 3               NaN               NaN                NaN         1.25
# 4               NaN               NaN                NaN         1.25
#
# [5 rows x 61 columns]

# %%
data.shape
# Out:
# (1913, 61)

# %%
1913-28
# Out:
# 1885

# %% [markdown]
# # Modeling

# %%
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn import preprocessing, metrics

from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.arima_model import ARIMA

# %%
x_train=data.iloc[:1885,1:]
y_train=data.iloc[:1885,:1]
x_test=data.iloc[1885:,1:]
y_test=data.iloc[1885:,:1]

# %%
# Simple smoothing
ss = SimpleExpSmoothing(y_train).fit(smoothing_level=0.2,optimized=False)
prediction_ss = ss.forecast(28)
score_ss=np.sqrt(metrics.mean_squared_error(prediction_ss, y_test))

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(y_train)

# %%
#ARIMA
arm = ARIMA(y_train.values,(2, 1, 7)).fit()
arm_prediction=arm.forecast(28)
score_arm=np.sqrt(metrics.mean_squared_error(arm_prediction[1], y_test))

# %%
score_arm
# Out:
# 39.572420308141865

# %%
arm.plot_predict(dynamic=False, start=1800)

# %%
x_train.head()
# Out:
#    wm_yr_wk  wday  month  year  snap_TX  sell_price  weekday_Friday  \
# 0     11101     1      1  2011        0        1.25               0
# 1     11101     2      1  2011        0        1.25               0
# 2     11101     3      1  2011        0        1.25               0
# 3     11101     4      2  2011        1        1.25               0
# 4     11101     5      2  2011        0        1.25               0
#
#    weekday_Monday  weekday_Saturday  weekday_Sunday  ...  \
# 0               0                 1               0  ...
# 1               0                 0               1  ...
# 2               1                 0               0  ...
# 3               0                 0               0  ...
# 4               0                 0               0  ...
#
#    event_type_1_Sporting  event_type_2_Cultural  event_type_2_Religious  \
# 0                      0                      0                       0
# 1                      0                      0                       0
# 2                      0                      0                       0
# 3                      0                      0                       0
# 4                      0                      0                       0
#
#    lag_t28  lag_t29  lag_t30  rolling_mean_t30  rolling_mean_t90  \
# 0      NaN      NaN      NaN               NaN               NaN
# 1      NaN      NaN      NaN               NaN               NaN
# 2      NaN      NaN      NaN               NaN               NaN
# 3      NaN      NaN      NaN               NaN               NaN
# 4      NaN      NaN      NaN               NaN               NaN
#
#    rolling_mean_t180  price_lag_1
# 0                NaN          NaN
# 1                NaN         1.25
# 2                NaN         1.25
# 3                NaN         1.25
# 4                NaN         1.25
#
# [5 rows x 60 columns]

# %%
#Random Forest
rf=RandomForestRegressor()
rf.fit(x_train.fillna(0).values,y_train)
prediction_rf=rf.predict(x_test)
score_rf=np.sqrt(metrics.mean_squared_error(prediction_rf, y_test))

# %%
#XG Boost
xg_reg = xgb.XGBRegressor()
xg_reg.fit(x_train.fillna(0).values,y_train)
prediction_xg_reg=xg_reg.predict(x_test.fillna(0).values)
score_xg_reg=np.sqrt(metrics.mean_squared_error(prediction_xg_reg, y_test))
# Out:
# [20:42:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
score_xg_reg
# Out:
# 25.56495770612705

# %%
score_rf
# Out:
# 34.49291852788668

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %%
# Simple smoothing
starting=90

plt.figure(figsize=(16,4))
plt.plot(np.arange(starting),y_train[-starting:] )
plt.plot(range(starting,starting+len(y_test)),y_test,color='red')
plt.plot(range(starting,starting+len(y_test)),fcast1,color='green')
plt.title("Simple Smoothing")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-efc1f9c7cd8c> in <module>
#       5 plt.plot(np.arange(starting),y_train[-starting:] )
#       6 plt.plot(range(starting,starting+len(y_test)),y_test,color='red')
# ----> 7 plt.plot(range(starting,starting+len(y_test)),fcast1,color='green')
#       8 plt.title("Simple Smoothing")
#       9
#
# NameError: name 'fcast1' is not defined

# %%
#ARIMA
starting=90

plt.figure(figsize=(16,4))
plt.plot(np.arange(starting),y_train[-starting:] )
plt.plot(range(starting,starting+len(y_test)),y_test,color='red')
plt.plot(range(starting,starting+len(y_test)),arm_prediction[0],color='green')
plt.title("ARIMA")

plt.show()

# %%
#Random Forest
starting=90

plt.figure(figsize=(16,4))
plt.plot(np.arange(starting),y_train[-starting:] )
plt.plot(range(starting,starting+len(y_test)),y_test,color='red')
plt.plot(range(starting,starting+len(y_test)),prediction_rf,color='green')
plt.title("Random Forest")

plt.show()

# %%
#XG Boost
starting=90

plt.figure(figsize=(16,4))
plt.plot(np.arange(starting),y_train[-starting:] )
plt.plot(range(starting,starting+len(y_test)),y_test,color='red')
plt.plot(range(starting,starting+len(y_test)),prediction_xg_reg,color='green')
plt.title("XGBoost")

plt.show()

# %% [markdown]
# # Score

# %%
plt.bar(['SS','ARIMA','RF','XGB'],[score_ss,score_arm,score_rf,score_xg_reg])
plt.ylabel('Root mean square error')
plt.show()
